# %%
[i for i in range(100) if i%3==0]
# Out:
# [0,
#  3,
#  6,
#  9,
#  12,
#  15,
#  18,
#  21,
#  24,
#  27,
#  30,
#  33,
#  36,
#  39,
#  42,
#  45,
#  48,
#  51,
#  54,
#  57,
#  60,
#  63,
#  66,
#  69,
#  72,
#  75,
#  78,
#  81,
#  84,
#  87,
#  90,
#  93,
#  96,
#  99]

# %%
for i in range(10):
    if i%2==0:
        print (i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
data = ['mani','puni','sasi','prem','gobi','durai']

# %%
[i for i in data if i[0]=='p']
# Out:
# ['puni', 'prem']

# %%
[i[0] for i in data]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-69a4ea594161> in <module>
# ----> 1 [i[0] for i in data]
#
# NameError: name 'data' is not defined

# %%
obj='manikandan'

# %%
obj[1]
# Out:
# 'a'

# %%
obj[-1]
# Out:
# 'n'

# %%
[i for i in data if i[-1]=='i']
# Out:
# ['mani', 'puni', 'sasi', 'gobi', 'durai']

# %%
[i for i in data if i in 'o']
# Out:
# []

# %%
for i in data:
#     print (i)
    for j in i:
        if j=='o':
            print (i)
# Out:
# gobi

# %%
4 in [1,2,3,4]
# Out:
# True

# %%
import pandas as pd

# %%
movies = pd.read_csv("http://bit.ly/imdbratings")
.

# %%
movies.to_dict('r')
# Out:
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:1549: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   warnings.warn(
# [{'star_rating': 9.3,
#   'title': 'The Shawshank Redemption',
#   'content_rating': 'R',
#   'genre': 'Crime',
#   'duration': 142,
#   'actors_list': "[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']"},
#  {'star_rating': 9.2,
#   'title': 'The Godfather',
#   'content_rating': 'R',
#   'genre': 'Crime',
#   'duration': 175,
#   'actors_list': "[u'Marlon Brando', u'Al Pacino', u'James Caan']"},
#  {'star_rating': 9.1,
#   'title': 'The Godfather: Part II',
#   'content_rating': 'R',
#   'genre': 'Crime',
#   'duration': 200,
#   'actors_list': "[u'Al Pacino', u'Robert De Niro', u'Robert Duvall']"},
#  {'star_rating': 9.0,
#   'title': 'The Dark Knight',
# ...

# %%
movies[movies.star_rating>9.0]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
mani = movies[(movies.star_rating>9.0) & (movies.duration<170)]['actors_list'][0]

# %%
mani
# Out:
# "[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']"

# %%
for i in eval(mani):
    print (i)
# Out:
# Tim Robbins
# Morgan Freeman
# Bob Gunton

# %%
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
data=['mani','puni','sasi','gobi','prem']
[i for i in data if i[0]=='p']
# Out:
# ['puni', 'prem']

# %%
obj='punitha'
obj[2]
# Out:
# 'n'

# %%
obj='anushka'
obj[0]
# Out:
# 'a'

# %%
obj='sujay'
obj[-1]
# Out:
# 'y'

# %%
data=['maha','bhuvi','divi','gayu','princy','kiru']
[i for i in data if i[0]=='h']
# Out:
# []

# %%
data=['maha','bhuvi','divi','gayu']
[i for i in data if i[0]=='h']
# Out:
# []

# %%
data=['maha','bhuvi','divi','gayu']
[i for i in data if i[0]=='h']
# Out:
# []

# %%
data=['maha','bhuvi','divi','gayu']
[i for i in data if i[0]=='i']
# Out:
# []

# %%
[if i for i in range(100) if i%2==0]
# Out:
#   File "<ipython-input-7-7644eb4b73b1>", line 1
#     [if i for i in range(100) if i%2==0]
#      ^
# SyntaxError: invalid syntax

# %%
[if i for i in range(100) if i%3==0]
# Out:
#   File "<ipython-input-8-979e5214dd9b>", line 1
#     [if i for i in range(100) if i%3==0]
#      ^
# SyntaxError: invalid syntax

# %%
[if i for i in range(100) if i%4==0]
